# %% [markdown]
# ### Exercise 1: Sales per hour during a week
#
# **Situation**
#
# A stock exchange company asked you to create a program to quickly obtain the weekly hourly sales statistics for Stock A. Specifically, the program should ask for each business hour of the week (45 hours) how many Stock A shares were sold in that hour, and what the average price of Stock A was at that hour. Upon completion of the program, it should return the total weekly sales (in terms of the number of Stock A shares and the total sales revenue).

# %% [markdown]
# **Question 1**
#
# Which command(s) are best for repeating the code 45 times?
#
# Response:
# Correct answer!
#
# Since they are loop-type commands that repeat a code a certain number of times. Remember that if-elif-else is used to execute certain actions given a logical operation.
#
# It's important to note that for is more efficient than while because for has built-in ability to repeat code a certain number of times. If you want to use while for this purpose, you need to take some additional considerations to achieve this.

# %% [markdown]
# **Question 2**

# %% [markdown]
# ### Exercise 2: Companies team building fieldtrip

# %% [markdown]
# 1. Que el usuario ingresa la cantidad de acciones vendidas en una hora mediante la siguiente línea de código:
#
# cantidad_de_acciones_vendidas=int(input("¿Cuántas acciones A se   vendieron en la hora "+str(i)+"?\n"))
# Código para completar:
#
# cantidad_total_de_acciones_vendidas = 0
# for i in range(0,45):
#            cantidad_de_acciones_vendidas=int(input("¿Cuántas acciones A se vendieron en la hora"+str(i)+"?\n"))
#  cantidad_total_de_acciones_vendidas = cantidad_de_acciones_vendidas
#  cantidad_total_de_acciones_vendidas +cantidad_de_acciones_vendidas
#  cantidad_total_de_acciones_vendidas = cantidad_total_de_acciones_vendidas*cantidad_de_acciones_vendidas
#  cantidad_total_de_acciones_vendidas = cantidad_total_de_acciones_vendidas+cantidad_de_acciones_vendidas
#
#
#
#  Solución Ejercicio
# Código de solución:
#
# cantidad_total_de_acciones_vendidas = 0
# recaudacion_total_de_acciones_vendidas = 0
#
# for i in range(0,45):
# 	cantidad_de_acciones_vendidas=int(input("¿Cuántas acciones A se vendieron en la hora "+str(i)+"?\n"))
# 	precio_promedio_accion=int(input("¿Cuál fue el precio promedio de la acción A en la hora "+str(i)+"?\n"))
# 	cantidad_total_de_acciones_vendidas = cantidad_total_de_acciones_vendidas+cantidad_de_acciones_vendidas
# 	recaudacion_total_de_acciones_vendidas = recaudacion_total_de_acciones_vendidas+cantidad_de_acciones_vendidas*precio_promedio_accion
#
# print("El total de acciones A vendidas en una semana fue: "+str(cantidad_total_de_acciones_vendidas))
# print("La recaudación total de acciones A vendidas en una semana fue: "+str(recaudacion_total_de_acciones_vendidas))
#
# -----
# Ejercicio formativo 2: Paseo de la empresa
#
# Situación
# Como programador, te pidieron crear un programa para poder organizar el paseo de fin de año de una empresa y dar algunos bonos.
#
# Para el paseo:
# Cada persona debe asignarse a un grupo distinto, que determinará su método de traslado y alojamiento. Se decidió hacer 4 grupos. No obstante, se desea que las personas se asignen aleatoriamente a cada grupo para mejorar las relaciones interpersonales entre todos los trabajadores.
#
# Para los bonos:
# Aquellos trabajadores que lleven más de 5 años trabajando en la empresa recibirán un bono que se calculará multiplicando los años trabajados por $12.000.
#
# La lógica de este programa es la siguiente:
# 1. Solicitar el nombre y apellido a un usuario.
# 2. Preguntarle al usuario cuántos años lleva trabajando en la empresa. A partir de esta información, calcular el bono.
# 3. Generar un número aleatorio entre 1 y 100. Con base en este número, asignar a la persona a los grupos de acuerdo al siguiente criterio:
#
# Si el número está entre 1 y 25 – Asignar al grupo A.
# Si el número está entre 26 y 50 – Asignar al grupo B.
# Si el número está entre 51 y 75 – Asignar al grupo C.
# Si el número está entre 76 y 100 – Asignar al grupo D.
# 4. Informar al usuario acerca del grupo al que fue asignado.
# -----
#
# Ordena las siguientes líneas de código para poder calcular el bono de cada persona.
#
# Puedes asumir que la variable años_de_trabajo ya está inicializada, es de tipo int, y contiene los años que lleva trabajando cada persona en la empresa.
#
# 1. print(“El bono que te corresponde es de: “+str(bono))
# 2.       bono = años_de_trabajo*12000
# 3. if años_de_trabajo>5:
# 4. else:
# 5.        bono = 0
#  1,2,3,4 y 5.
#  2,3,4,1 y 5.
#  3,4,5,1 y 2.
#  3,2,4,5 y 1.
#
#
#  Your answer :
# 3,2,4,5 y 1.
#
# Response:
# ¡Respuesta correcta!
#
# El orden correcto es 3,2,4,5,1. El código se ve de la siguiente forma:
#
# if años_de_trabajo>5:
#
#   bono = años_de_trabajo*12000
#
# else:
#
#   bono = 0
#
# print(“El bono que te corresponde es de: “+str(bono))
# Lo primero por notar, es que no podemos informar del bono antes de calcularlo.
#
# Segundo, como el bono se otorga solo a los trabajadores que lleven más de 5 años trabajando, entonces esta debe ser nuestra condición del if y la primera línea de comandos de nuestro código. Además, la indentación nos indica qué líneas van dentro de cada if.
#
# Finalmente, y por la lógica del flujo, ubicamos el else después del if.
#
# -----
# Indica si el siguiente enunciado es verdadero o falso:
#
# "Este código asigna aleatoriamente a una persona a un grupo según la lógica del programa expuesta anteriormente".
#
# import random
# numero_aleatorio = random.randint(1,100)
# print(numero_aleatorio)
#
# elif numero_aleatorio>=1 and numero_aleatorio<=25:
# 	print("Estimado/a "+nombre+" "+apellido+" Fuiste asignado al grupo A.")
# elif numero_aleatorio>=26 and numero_aleatorio<=50:
# 	print("Estimado/a "+nombre+" "+apellido+" Fuiste asignado al grupo B.")
# elif numero_aleatorio>=51 and numero_aleatorio<=75:
# 	print("Estimado/a "+nombre+" "+apellido+" Fuiste asignado al grupo C.")
# else:
# 	print("Estimado/a "+nombre+" "+apellido+" Fuiste asignado al grupo D.")
#
#
# Falso
#
# Verdadero
#
# Your answer :
# Falso
#
# Response:
# ¡Respuesta correcta!
#
# La secuencia de if-elif-else empieza con "elif", lo que arroja un error en Python. Para que esto funcionara, y pudiéramos asignar correctamente a una persona a un grupo, entonces debería partir con "if".
#
# ----
#
# Solución del ejercicio
# Código de solución:
# import random
#
# nombre = input("Ingresa tu nombre\n")
#
# apellido = input("Ingresa tu apellido\n")
#
# años_de_trabajo = int(input("¿Cuántos años llevas trabajando en la empresa?\n"))
#
# if años_de_trabajo>5:
# 	bono = años_de_trabajo*12000
# else:
# 	bono = 0
#
# print("El bono que te corresponde es de: "+str(bono))
#
# numero_aleatorio = random.randint(1,100)
# print(numero_aleatorio)
#
# if numero_aleatorio>=1 and numero_aleatorio<=25:
# 	print("Estimado/a "+nombre+" "+apellido+" Fuiste asignado al grupo A.")
# elif numero_aleatorio>=26 and numero_aleatorio<=50:
# 	print("Estimado/a "+nombre+" "+apellido+" Fuiste asignado al grupo B.")
# elif numero_aleatorio>=51 and numero_aleatorio<=75:
# 	print("Estimado/a "+nombre+" "+apellido+" Fuiste asignado al grupo C.")
# elif numero_aleatorio>=76 and numero_aleatorio<=100:
# 	print("Estimado/a "+nombre+" "+apellido+" Fuiste asignado al grupo D.")

# %% [markdown]
# ### Sumativa
#
# Situación:
# Una empresa está organizando las vacaciones de sus trabajadores y pidió ayuda. Específicamente, necesitan un programa que ayude a saber cuánta gente habrá de vacaciones durante el mes de enero.
# Además, quieren saber el detalle por área, considerando que la empresa tiene las áreas de Administración, Ventas y Operaciones. El sistema debe ser capaz de ir preguntando a los 25 trabajadores de la empresa su nombre, área, si tomarán vacaciones y cuántos días tomarán. Antes de finalizar, el sistema debe entregar un resumen de cuántas personas tomarán vacaciones y la cantidad de días de vacaciones por área. Puedes asumir que nadie pedirá más vacaciones de las que les corresponde y que tampoco se equivocarán al ingresar la información.
#
#
# Ordena de manera secuencial  (del número 1 al 5) los distintos pasos que componen la lógica completa del programa, de tal forma que puedan cumplir las necesidades que te pidió la empresa.
#
# 4 Aumentar en uno la cantidad de personas que tomarán vacaciones y la cantidad de días de vacaciones del área correspondiente según lo que respondió el trabajador anteriormente.
#
# 5 Reportar cuántos trabajadores tomarán vacaciones en total y por área.
#
# 3 Preguntar cuántos días tomará de vacaciones y a qué área pertenece el trabajador.
#
# 2 Preguntar al trabajador si tomará vacaciones o no.
#
# 1 Repetir 25 veces lo anterior.
#
# Respuesta parcialmente correcta.
#
# You have correctly selected 1.
# Al seguir los requerimientos de la empresa:
#
# •Uno debe preguntar primero si el trabajador tomará vacaciones (no tiene sentido preguntar el área y los días de vacaciones si no tomarán vacaciones).
# •Luego debe preguntar cuántos días tomará de vacaciones y a qué área pertenece (para poder agregar los días de vacaciones al área).
# •A continuación, aumentar en 1 la cantidad de personas que tomarán vacaciones y se debe agregar los días de vacaciones a esa área.
# •Esto es el flujo para una persona, por lo tanto se debe repetir 25 veces. No tiene sentido tampoco repetirlo antes de haber hecho este flujo para la primera persona.
# •Finalmente, uno puede imprimir el resumen de días de vacaciones por área y la cantidad total de personas que tomará vacaciones (no tiene sentido hacerlo antes de las 25 repeticiones).
#
#
# ----
#
# Indica si la afirmación es verdadera o falsa:
#
# "Lo que se imprimirá en consola después de ejecutar el código A es exactamente igual al código B".
#
# Código A:
#
# for i in range(5,10):
# 	print(i)
#
# Código B:
#
# i = 5
# while i<=10:
# 	print(i)
# 	i = i+1
#
# Question 2 Select one:
# True
# **False**
#
#
# ----
#
# ¿Cuál de las siguientes opciones define de mejor manera al ciclo que debe repetirse 25 veces?
# Question 3 Select one:
# a.
# while True:
# **b.for i in range(0,25):**
# c.
# for i in range(1,25):
# d.
# while i == 25:
#
#
# ---
#
# Asumamos que el trabajador ocupó este comando para indicar si tuvo o no vacaciones: tomara_vacaciones = input("Escribe SÍ o NO para indicar si tomarás vacaciones\n")
# ¿Cuál de las siguientes opciones corresponde a la implementación correcta para saber si el trabajador dijo que SÍ, y por ende continuar la lógica del programa?
#
# Question 4 Select one:
# **a.if tomara_vacaciones == “SÍ”:**
# b.
# elif tomara_vacaciones == “SÍ”:
# c.
# if tomara_vacaciones = “SÍ”:
# d.
# else tomara_vacaciones == “SÍ”:
#
#
# ----
#
#
# ¿Qué se imprimirá en consola una vez que se ejecute este código?
#
# for i in range(0,20):
# 	if i%2==0:
# 		print(i)
# Question 5 Select one:
# **a.Los números pares entre 0 y 19.**
#
# b.
# Los números del 0 al 19.
#
# c.
# Nada.
#
# d.
# Los números impares entre 0 y 19.
#
# ----
#
# ¿Cuál de las siguientes alternativas NO corresponde a la estructura if-elif-else para poder determinar a qué área de la empresa pertenece un trabajador?
#
# Asuma que esto se le pidió al trabajador mediante la siguiente línea de código:
#
#
# area = input("¿A qué area de la empresa perteneces? Escribe VENTAS, OPERACIONES o ADMINISTRACIÓN\n")
#
# Question 6 Select one:
# a.
# elif area == "OPERACIONES":
# b.
# if area == "VENTAS":
# c.
# elif area == "ADMINISTRACIÓN":
# **d.else**
#
# ----
#
# Este código es una posible solución al problema planteado al inicio. La persona que lo programó es principiante, por lo tanto, a pesar que cumple completamente con lo pedido puede que tenga algunas líneas de código extras.
#
# Recuerda que puedes copiar el código en la consola, para  visualizar los colores y numeración de cada línea.
#
# El código es el siguiente:
#
# personas_con_vacaciones = 0
# cantidad_total_de_personas_que_pidieron_vacaciones = 0
# cantidad_total_de_personas_que_pidieron_vacaciones2 = 0
# dias_vacaciones_ventas = 0
# dias_vacaciones_ventas2 = 0
# dias_vacaciones_operaciones = 0
# dias_vacaciones_operaciones2 = 0
# dias_vacaciones_administración = 0
#
#
# for i in range(0,25):
#     tomara_vacaciones = input("Escribe SÍ o NO para indicar si tomarás vacaciones\n")
#     cantidad_total_de_personas_que_pidieron_vacaciones = cantidad_total_de_personas_que_pidieron_vacaciones + 1
#
#     if tomara_vacaciones == "SÍ":
#         personas_con_vacaciones = personas_con_vacaciones + 1
#
#         dias_vacaciones = int(input("¿Cuántos dias tomarás de vacaciones?\n"))
#
#         area = input("¿A qué area de la empresa perteneces? Escribe VENTAS, OPERACIONES o ADMINISTRACIÓN\n")
#
#         dias_vacaciones_operaciones2 = dias_vacaciones_operaciones2 + dias_vacaciones
#
#         if area == "VENTAS":
#             dias_vacaciones_ventas2 = dias_vacaciones_ventas2 + dias_vacaciones
#             dias_vacaciones_ventas = dias_vacaciones_ventas + 1
#         elif area == "OPERACIONES":
#             dias_vacaciones_operaciones = dias_vacaciones_operaciones + dias_vacaciones
#         elif area == "ADMINISTRACIÓN":
#             dias_vacaciones_administración = dias_vacaciones_administración + dias_vacaciones
#         else:
#             cantidad_total_de_personas_que_pidieron_vacaciones2 = cantidad_total_de_personas_que_pidieron_vacaciones2 + 1
#
#
# print("La cantidad total de personas que tomarán vacaciones son: "+str(personas_con_vacaciones))
#
# print("La cantidad de días de vacaciones en el área de VENTAS es: "+str(dias_vacaciones_ventas))
#
# print("La cantidad de días de vacaciones en el área de OPERACIONES es: "+str(dias_vacaciones_operaciones))
#
# print("La cantidad de días de vacaciones en el área de ADMINISTRACIÓN es: "+str(dias_vacaciones_administración))
#
#
# En base al código anterior, ¿cómo podríamos modificarlo para que el programa funcionara para 100 trabajadores?
#
# Question 7 Select one:
# **a.Cambiar “for i in range(0,25):” a “for i in range(0,100)”:**
#
# b.
# Cambiar “for i in range(0,25):” a “for i in range(1,100)”:
# c.
# Cambiar “for i in range(0,25):” a “while range(0,100)”:
# d.
# Cambiar “for i in range(0,25):” a “for i in range(25,100)”:
#
# ----
#
# Al finalizar la ejecución del código, ¿en qué variable podemos encontrar la cantidad de personas que tomarán vacaciones?
#
# Question 8 Select one:
# a.
# cantidad_total_de_personas_que_pidieron_vacaciones
# **b.personas_con_vacaciones**
# c.
# dias_vacaciones_ventas
# d.
# cantidad_total_de_personas_que_pidieron_vacaciones2
#
# ----
#
# Al finalizar la ejecución del código, ¿en qué variable podemos encontrar la cantidad de días de vacaciones del área de OPERACIONES?
#
# Question 9 Select one:
# a.
# dias_vacaciones_ventas
#
# **b.dias_vacaciones_operaciones**
# c.
# personas_con_vacaciones
#
# d.
# dias_vacaciones_operaciones2
#
# ----
#
# Al finalizar la ejecución del código, ¿en qué variable podemos encontrar la cantidad de días de vacaciones del área de VENTAS?
#
# Question 10 Select one:
# a.
# personas_con_vacaciones
#
# **b.dias_vacaciones_ventas2**
# c.
# dias_vacaciones_operaciones2
# d.
# dias_vacaciones_ventas
#
#
# ----
