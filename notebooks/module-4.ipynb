# %% [markdown]
# Excercise 1. Representación de base de datos de productos
#
# Eres el encargado de informática de una empresa. Recientemente empezaron a trabajar con un nuevo proveedor. No obstante, él tiene un sistema bastante obsoleto, y antes de poder procesar los datos de sus productos, debes armar una matriz de datos que sea capaz de soportarla. Por el sistema y problemas del proveedor, ellos tampoco saben cuántos productos tienen. La base de datos de este proveedor se ve de la siguiente manera:
#
# ![data table](../images/Tabla_e_5.png)

# %% [markdown]
# Question 1.
#
# Si la base de datos anterior se guarda en un código de Python como una lista de listas de nombre matriz_de_datos, ¿cómo podríamos obtener el stock del producto que se encuentra en la tercera fila?
#
# Puede asumir que matriz_de_datos no tiene una primera fila con el nombre de cada columna.
#
# matriz_de_datos[2][columna=3]
#
# matriz_de_datos[fila=2][columna="stock"]
#
# **matriz_de_datos[2][3]**
#
# matriz_de_datos[fila=3][columna="stock"]

# %% [markdown]
# **Question 2.**
#
# Si la base de datos anterior se guarda en un código de Python como una lista de listas de nombre matriz_de_datos, ¿cuál de estas opciones nos permite saber la cantidad de productos de la base de datos?
#
# matriz_de_datos.len()
#
# matriz_de_datos.len([0])
#
# **len(matriz_de_datos)**
#
# len(matriz_de_datos[0])

# %% [markdown]
# **Question 3.**
#
# Indica si el planteamiento es verdadero o falso:
#
# El proveedor nos acaba de informar que debemos cambiar precio al producto con SKU 254651 a 14250.
# La base de datos anterior, se guarda en un código de Python como una lista de listas de nombre matriz_de_datos.
# Para lograr resolver la solicitud, se hará mediante el siguiente código:
# for i in range(0,len(matriz_de_datos)):
#
#           if matriz_de_datos[i][0] == 254651:
#
#                      matriz_de_datos[i][2] = 14250
#
# ¿Crees que este código permite cambiar el precio del producto con SKU 254651?
#
#
# Puede asumir que el SKU está guardado como número.
#
#
# Falso
#
# **Verdadero**

# %% [markdown]
# ### Exercise 2. Archivo CSV de un proveedor
#
# Eres el encargado de informática de una empresa. Recientemente empezaron a trabajar con un nuevo proveedor. No obstante, él tiene un sistema bastante obsoleto, y antes de poder procesar los datos de sus productos, debes armar una matriz de datos que sea capaz de soportarla. Por el sistema y problemas del proveedor, ellos tampoco saben cuántos productos tienen. La base de datos de este proveedor se ve de la siguiente manera:
#
# ![data table](../images/Tabla_e_5.png)

# %% [markdown]
# **Question 1.**
#
# Para armar tu matriz_de_datos, debes leer un archivo CSV. Si el archivo CSV que te pasó el proveedor se llama “productos.csv”, ¿cuál de estas opciones representa de mejor manera el código para poder crear matriz_de_datos a partir del archivo CSV?
#
# **CORRECTA**
# archivo = open("productos.csv")
#
# archivo_en_lineas = archivo.readlines()
#
# archivo.close()
#
# matriz_de_datos = []
#
# for linea in archivo_en_lineas:
# 	fila = linea.split(";")
# 	matriz_de_datos.append(fila)
#
#
# ---
#
# archivo = open("productos.csv")
#
# archivo_en_lineas = archivo.readlines()
#
# archivo.close()
#
# matriz_de_datos = archivo_en_lineas
#
#
# ---
#
#
# archivo = open("productos.csv")
#
# archivo_en_lineas = archivo.read()
#
# archivo.close()
#
# matriz_de_datos = []
#
# for linea in archivo_en_lineas:
# 	fila = linea.split(";")
# 	matriz_de_datos.append(fila)
#
# ---
#
#
# archivo = open("productos.csv")
#
# archivo_en_lineas = archivo.readlines()
#
# archivo.close()
#
# matriz_de_datos = []
#
# for linea in archivo_en_lineas:
# 	matriz_de_datos.append(linea)

# %% [markdown]
# **Question 2.**
#
# Al leer el archivo CSV, nos damos cuenta que la columna NOMBRE viene en este formato:
#
# "_<Producto1"
#
# "_<Producto2"
#
# "_<Producto3"
#
# …
#
# Por lo tanto, se debe limpiar la columna de los caracteres indeseados, también es necesaraio considerar que los  datos cargados están en la variable matriz_de_datos.
#
# ¿Cuál de las siguientes opciones cumpliría mejor la labor de limpiar esta columna según lo especificado?
#
#
# for fila in matriz_de_datos:
# 	nombre_prod = fila[2]
# 	fila[2] = nombre_prod[2:len(nombre_prod)]
# ---
#
# for fila in matriz_de_datos:
# 	nombre_prod = fila[2]
# 	fila[2] = nombre_prod.strip()
# ---
# **CORRECTA**
# for fila in matriz_de_datos:
# 	nombre_prod = fila[1]
# 	fila[1] = nombre_prod[2:len(nombre_prod)]
# ---
#
# for fila in matriz_de_datos:
# 	nombre_prod = fila[1]
# 	fila[1] = nombre_prod.strip()

# %% [markdown]
# **Question 2.**
#
# Indica si la siguiente afirmación es verdadero o falso:
#
# "Ahora queremos guardar nuestra base de datos limpia, para lo que es necesario ocupar un  código, pero ya sabemos que:
#
#  matriz_de_datos ya está creada y con la columna NOMBRE “limpia”.
#
#  se debe guardar esta información en un archivo CSV de nombre “matriz_limpia.csv”.
#
# Entonces el código correcto es:
#
# archivo_guardar = open("matriz_limpia.csv","w")
#
# for fila in matriz_de_datos:
# 	fila_para_escribir = ""
#
# 	for i in range(0,len(fila)):
# 			fila_para_escribir += fila[i] + ";"
#
# 	fila_para_escribir += "\n"
#
# 	archivo_guardar.write(fila_para_escribir)
#
# archivo_guardar.close()
#
#
# **Falso**
#
# Verdadero
#
#
#
# ---
#
# Se está agregando un ";" extra, lo que significará una columna vacía nueva cuando carguemos nuevamente esta matriz.
#
# Recordemos que en los archivos CSV las columnas se separan por ";" o ",".  Faltaría este pedazo de código dentro del for anidado en cada fila:
#
# if i == len(fila)-1:
#
# 	fila_para_escribir += str(fila[i])
#
# else:
#
# 	fila_para_escribir += fila[i] + ";"
# Que agrega ";" en las columnas pero no en la última.

# %% [markdown]
# ## Final module test
#
# **Situación:**
#
# Supongamos que entraste a trabajar a una empresa que tenía la información de sus empleados en un archivador. Como encargado de informática, te pidieron crear un sistema que pueda administrar esta información. Específicamente, las fichas de cada empleados contienen la siguiente información:
#
# - RUT
# - Nombre
# - Fecha de nacimiento
# - Edad
# - Remuneración
# - Fecha de contratación

# %% [markdown]
# **Q1** Indica si el siguiente enunciado es verdadero o falso:
#
# "Para poder cargar la información del archivador a Python es recomendable ocupar un archivo Word".
# Question 1 Select one:
#
#
# - True
# - **False**
#
# ---
#
# La respuesta es Falso:
# Esto dado que como se enseñó durante el módulo, la información debería cargarse en un archivo CSV como una base de datos, para que su lectura sea más fácil y luego pueda transformarse en una matriz de datos.

# %% [markdown]
# **Q2**
# Como experto en informática, guardarás la información del archivador en un archivo CSV para poder cargarla más fácilmente a Python y luego poder procesarla.
# Si queremos añadir una fila al archivo CSV para agregar la siguiente información:
# •RUT: 16.533.123-1
# •Nombre: Juan Andrés González Henríquez
# •Fecha de nacimiento: 31/07/1991
# •Edad: 27
# •Remuneración: 500000
# •Fecha de contratación: 03/01/2015
# ¿Cuál(es) de estas opciones sería(n) la(s) más adecuada(s) para agregar esta fila al archivo CSV?
#
# Question 2 Select one or more:
#
# a.16.533.123-1/Juan Andrés González Henríquez/31/07/1991/27/500000/03/01/2015\n
#
# **b.16.533.123-1;Juan Andrés González Henríquez;31/07/1991;27;500000;03/01/2015\n**
#
# c.16.533.123-1\nJuan Andrés González Henríquez\n 31/07/1991\n27\n500000\n03/01/2015
#
# **d.16.533.123-1,Juan Andrés González Henríquez,31/07/1991,27,500000,03/01/2015\n**

# %% [markdown]
# **Info** De aquí en adelante, asuma que la información de los empleados de la empresa en todos los ejercicios se almacenará con este formato:
#
# ![data table](../images/retro_m3_p2.png)

# %% [markdown]
# **Q3**
#
# Ya tenemos nuestro archivo CSV formado a partir de la base de datos. Por lo tanto, ahora queremos “cargarlo” en Python.
# ¿Cuál de las siguientes opciones es la más adecuada para almacenar esta información en Python?
# Question 3 Select one:
#
# a.
# Variable.
#
# b.
# Lista.
#
# c.
# Archivo.
#
# **d.Lista de listas.**

# %% [markdown]
# **Q4**
#
# Si el archivo CSV se llama “empleados.csv”, ¿cuál de las siguientes opciones corresponde a las líneas de código faltantes para poder cargar la información del archivo CSV a una lista de listas llamada base_de_datos?
#
# El código a rellenar es el siguiente:
#
# var_archivo = open("empleados.csv","r")
# lineas = var_archivo.readlines()
# base_de_datos = []
# (línea 1)
# (línea 2)
# Question 4 Select one:
#
# **a. Línea 1: for i in lineas:**
# **Línea 2:   base_de_datos.append(i.split(“;”))**
#
# b.
# Línea 1: for i in lineas:
# Línea 2:   base_de_datos.append(split(i,“;”))
#
# c.
# Línea 1: for i in range(len(lineas)):
# Línea 2:   base_de_datos.append(i)
#
# d.
# Línea 1: for i in range(lineas):
# Línea 2: base_de_datos.append(i)

# %% [markdown]
# **Q5**
#
# ¿Cuál de las siguientes líneas de código me permite imprimir en consola, la información del último empleado de la lista de listas “base_de_datos?
# Question 5 Select one:
#
# a.
# print(base_de_datos[base_de_datos.len()-1])
#
# b.
# print(base_de_datos[len(base_de_datos)])
#
# c.
# print(base_de_datos[base_de_datos.len()-1])
#
# **d.print(base_de_datos[len(base_de_datos)-1])**

# %% [markdown]
# **Q6**
#
# Si sabemos que la empleada de nombre “Paula Andrea Araya Rojas” está en la fila 251, ¿cuál de estas opciones representa al código que imprime en consola el siguiente string?
#
# “Paula Andrea Araya Rojas , con RUT 10.912.836-4, empezó a trabajar en la empresa el 04/06/2009”.
#
# Puedes asumir que la información de los empleados se encuentra en la lista de listas “base_de_datos.
#
# Question 6 Select one:
#
# a.
# print(base_de_datos[251][1]+”, con RUT “+base_de_datos[251][0]+”, empezó a trabajar en la empresa el “+base_de_datos[250][5])
#
# b.
# print(base_de_datos[251][1]+”, con RUT “+base_de_datos[250][0]+”, empezó a trabajar en la empresa el “+base_de_datos[251][5])
#
# c.
# print(base_de_datos[250][2]+”, con RUT “+base_de_datos[250][1]+”, empezó a trabajar en la empresa el “+base_de_datos[251][6])
#
# **d.print(base_de_datos[250][1]+”, con RUT “+base_de_datos[250][0]+”, empezó a trabajar en la empresa el “+base_de_datos[250][5])**

# %% [markdown]
# **Q7**
#
# Si sabemos que la información de los empleados se encuentra en la lista de listas “base_de_datos” y que el año actual es 2018.
# ¿Cuál de las siguientes opciones corresponde a las líneas de código faltantes para poder crear una nueva columna que indique la cantidad de años trabajados?
# El código a completar es el siguiente:
# for linea in base_de_datos:
#   año_contratacion = int(linea[5].split("/")[2]))
#
#    (línea 1)
#    (línea 2)
#
# Question 7 Select one:
#
# a.
# Línea 1: años_de_trabajo = 2018-año_contratacion
# Línea 2: linea.append(año_contratacion)
#
# b.
# Línea 1: años_de_trabajo = 2018-año_contratacion
# Línea 2: base_de_datos[linea] = años_de_trabajo
#
# c.
# Línea 1: años_de_trabajo = 2018-año_contratacion
# Línea 2: base_de_datos.append(años_de_trabajo)
#
# **d.Línea 1: años_de_trabajo = 2018-año_contratacion**
# **Línea 2: linea.append(años_de_trabajo)**

# %% [markdown]
# **Q8**
#
# Se puede asumir que la información de los empleados se encuentra en la lista de listas “base_de_datos”. Por lo tanto, cada fila de esta lista de lista corresponde a un empleado y sus columnas corresponden a sus características.
# ¿Cuál es el problema del siguiente código al intentar guardar el valor de base_de_datos en un archivo de tipo CSV?
# archivo_guardar = open("archivo_base_de_datos.csv","w")
#
# for fila in base_de_datos:
#
# 	archivo_guardar.write(str(fila)+"\n")
#
# archivo_guardar.close()
#
# Question 8 Select one:
#
# **a.En el archivo "archivo_base_de_datos.csv", no se guarda la lista de listas base_de_datos en formato CSV.**
#
# b.
# El archivo abierto no se cierra, por lo tanto no se guarda lo que se escribe en él.
#
# c.
# "archivo_base_de_datos.csv" debe abrirse en modo "o", de "open".
#
# d.
# No se guardan todas las filas de base_de_datos.

# %% [markdown]
# **Q9**
#
# Si sabemos que la información de los empleados se encuentra en la lista de listas “base_de_datos”, y de pronto, nos damos cuenta que algunas de las filas del archivo CSV vienen en el siguiente formato:
#
# \t16.533.123-1;Juan Andrés González Henríquez;31/07/1991;27;500000;03/01/2015\n
# Es decir, el RUT viene “sucio” en algunas filas.
# ¿Cuál de estas opciones corresponde a las líneas de código faltantes para poder limpiar la columna en cada una de las filas?
# Question 9 Select one:
#
# a.
# for linea in base_de_datos:
#
#          linea = linea[0].strip()
#
# b.
# for linea in base_de_datos:
#
#           linea[0] = linea.strip()
#
# **c**.
# **for linea in base_de_datos:**
#     **linea[0] = linea[0].strip()**
#
# d.
# for linea in base_de_datos:
#
#          linea[1] = linea[1].strip()

# %% [markdown]
# **Q10**
#
#
# Indica si el siguiente enunciado es verdadero o falso:
#
# El código puede guardar matriz_de_datos en un archivo en formato CSV:
#
# archivo_guardar = open("base_de_datos.csv","w")
#
# for fila in matriz_de_datos:
#         fila_para_escribir = ""
#
#         for i in range(0,len(fila)):
#                 if i == len(fila)-1:
#                         fila_para_escribir += str(fila[i])
#                 else:
#                         fila_para_escribir += fila[i]
#
#         fila_para_escribir +=fila+"\n"
#
#         archivo_guardar.write(fila_para_escribir)
#
# archivo_guardar.close()
#
# Question 10 Select one:
#
# True
#
# **False**
#
# ---
#
#
# La respuesta correcta es Falso.
# for fila in matriz_de_datos:
# fila_para_escribir = ""
# for i in range(0,len(fila)):
# if i == len(fila)-1:
# fila_para_escribir += str(fila[i])
# else:
# fila_para_escribir += fila[i]
# fila_para_escribir += "\n"
# archivo_guardar.write(fila_para_escribir)
# archivo_guardar.close()
#
# La fila 8 debería ser:
# fila_para_escribir += str(fila[i]) + “;”
#
# Como se puede ver en las clases en el ejemplo práctico. Esto sirve para poder separar la información de cada columna con un “;”, y así respetar el formato CSV.
